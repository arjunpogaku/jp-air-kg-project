# %%
import pandas as pd

# Read the first 5 rows of the CSV file into a DataFrame
# The 'nrows' parameter limits the number of rows read
df = pd.read_csv('~/jp_air_kg_project/artifacts/feature_table.csv', nrows=2)

# Print the resulting DataFrame
print(df)
# Out:
#            TID        SID        Prefecture    City        Street   Pincode  \
# 0  T2020021221  S12211510  Chiba Prefecture  Narita  Narita-kaido  286-0025
# 1  T2020021220  S12211510  Chiba Prefecture  Narita  Narita-kaido  286-0025
#
#    Hour  Year     Month        Day  ... CO_label Ox_label NMHC_label  \
# 0    21  2020  February  Wednesday  ...     safe      NaN        NaN
# 1    20  2020  February  Wednesday  ...     safe      NaN        NaN
#
#   CH4_label  THC_label  SPM_label  SP_label  WS_label  TEMP_label  HUM_label
# 0       NaN        NaN       safe       NaN       NaN         NaN        NaN
# 1       NaN        NaN       safe       NaN       NaN         NaN        NaN
#
# [2 rows x 46 columns]
